# %% [markdown]
# ## Langchain version v1

# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
os.environ["OPENAI_API_KEY"] = os.environ.get("OPENAI_API_KEY")

# %%
def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

agent = create_agent(
    model=model,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)


response = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "What is the weather like in New York?"
        }
    ]
})

print(response)
# Out:
# {'messages': [HumanMessage(content='What is the weather like in New York?', additional_kwargs={}, response_metadata={}, id='a34afa62-d95c-490b-bf2f-2a6891a43711'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"city": "New York"}'}, '__gemini_function_call_thought_signatures__': {'9f4dc1db-e63e-43b1-8c13-f7d39b54b453': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e6ce6-5376-7470-be58-cb19709c8c00-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'New York'}, 'id': '9f4dc1db-e63e-43b1-8c13-f7d39b54b453', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 67, 'total_tokens': 121, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 51}}), ToolMessage(content='The weather in New York is sunny.', name='get_weather', id='3c0c3d8d-3eba-4d6c-84e1-a674ea2c2b4b', tool_call_id='9f4dc1db-e63e-43b1-8c13-f7d39b54b453'), AIMessage(content='The weather in New York is sunny.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e6ce6-5aa8-7e52-9769-29b6a48823e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 8, 'total_tokens': 100, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response["messages"][-1].content)
# Out:
# The weather in New York is sunny.
